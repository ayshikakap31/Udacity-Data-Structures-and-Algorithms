# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

def find_files(suffix: str, path: str) -> list[str]:
    """
    Find all files beneath path with file name suffix.

    Note that a path may contain further subdirectories
    and those subdirectories may also contain further subdirectories.

    There are no limit to the depth of the subdirectories can be.

    Parameters:
    -----------
    suffix : str
        The suffix of the files to be found.
    path : str
        The root directory path where the search should begin.

    Returns:
    --------
    list[str]
        A list of file paths that end with the given suffix.
    """
    files = []
    for en in os.listdir(path):
      full_path = os.path.join(path,en)
      if os.path.isfile(full_path):
        if full_path.endswith(suffix):
          files.append(full_path)
      elif os.path.isdir(full_path):
        files.extend(find_files(suffix, full_path))
    return files


if __name__ == "__main__":
    files = []
    # Test Case 1: Standard test case with known structure
    print("Test Case 1: Standard directory structure")
    result = find_files(".c", "/content/drive/My Drive/testdir")
    print(result)
    # Expected output: ['./testdir/subdir1/a.c', './testdir/subdir3/subsubdir1/b.c', './testdir/subdir5/a.c', './testdir/t1.c']

    # Test Case 2
    result2 = find_files(".h", "/content/drive/My Drive/testdir")
    print(result2)

    # Test Case 3
    result3 = find_files(".gitkeep", "/content/drive/My Drive/testdir")
    print(result3)
# Out:
# Test Case 1: Standard directory structure
# ['/content/drive/My Drive/testdir/t1.c', '/content/drive/My Drive/testdir/subdir5/a.c', '/content/drive/My Drive/testdir/subdir1/a.c', '/content/drive/My Drive/testdir/subdir3/subsubdir1/b.c']
# ['/content/drive/My Drive/testdir/subdir5/a.h', '/content/drive/My Drive/testdir/t1.h', '/content/drive/My Drive/testdir/subdir1/a.h', '/content/drive/My Drive/testdir/subdir3/subsubdir1/b.h']
# ['/content/drive/My Drive/testdir/subdir4/.gitkeep', '/content/drive/My Drive/testdir/subdir2/.gitkeep']
